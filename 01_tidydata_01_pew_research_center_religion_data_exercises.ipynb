# %%
from datetime import datetime
from plotnine import *
import pandas as pd

import numpy as np
import re

# %% [markdown]
# # 1 . Pew Research Center Dataset [link](https://www.pewforum.org/datasets/)

# %%
# read the data
data_path = "https://raw.githubusercontent.com/frandiego/data/master/pew.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#              religion  <$10k  $10-20k  ...  $100-150k  >150k  Don't know/refused
# 0            Agnostic     27       34  ...        109     84                  96
# 1             Atheist     12       27  ...         59     74                  76
# 2            Buddhist     27       21  ...         39     53                  54
# 3            Catholic    418      617  ...        792    633                1489
# 4  Don’t know/refused     15       14  ...         17     18                 116
#
# [5 rows x 11 columns]

# %% [markdown]
# ### 1.1. Melt the dataframe, using `religion`, the variable name should be `income`and the value name `population`.

# %%
# here your code

# %%
# Out:
#              religion income  population
# 0            Agnostic  <$10k          27
# 1             Atheist  <$10k          12
# 2            Buddhist  <$10k          27
# 3            Catholic  <$10k         418
# 4  Don’t know/refused  <$10k          15

# %% [markdown]
# ### 1.2 Sort values by religion and income and reset the index

# %%
# here your code

# %%
df.head(10)
# Out:
#    religion              income  population
# 0  Agnostic             $10-20k          34
# 1  Agnostic           $100-150k         109
# 2  Agnostic             $20-30k          60
# 3  Agnostic             $30-40k          81
# 4  Agnostic             $40-50k          76
# 5  Agnostic             $50-75k         137
# 6  Agnostic            $75-100k         122
# 7  Agnostic               <$10k          27
# 8  Agnostic               >150k          84
# 9  Agnostic  Don't know/refused          96

# %%
df.tail(10)
# Out:
#          religion              income  population
# 170  Unaffiliated             $10-20k         299
# 171  Unaffiliated           $100-150k         321
# 172  Unaffiliated             $20-30k         374
# 173  Unaffiliated             $30-40k         365
# 174  Unaffiliated             $40-50k         341
# 175  Unaffiliated             $50-75k         528
# 176  Unaffiliated            $75-100k         407
# 177  Unaffiliated               <$10k         217
# 178  Unaffiliated               >150k         258
# 179  Unaffiliated  Don't know/refused         597

# %% [markdown]
# ### 1.3 What's happened with column `income`?
# * Read what is a pandas.Categorical variable [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html)
# * Convert `income` into a pandas.Categorical column

# %%
categories = ["<$10k", "$10-20k", "$20-30k", "$30-40k", "$40-50k", "$50-75k", "$75-100k", "$100-150k", ">150k", "Don't know/refused"]

# %%
# here your code

# %% [markdown]
# ### 1.4 Sort by `religion`  and `income` again

# %%
# here your code

# %%
df.head(10)
# Out:
#    religion              income  population
# 0  Agnostic               <$10k          27
# 1  Agnostic             $10-20k          34
# 2  Agnostic             $20-30k          60
# 3  Agnostic             $30-40k          81
# 4  Agnostic             $40-50k          76
# 5  Agnostic             $50-75k         137
# 6  Agnostic            $75-100k         122
# 7  Agnostic           $100-150k         109
# 8  Agnostic               >150k          84
# 9  Agnostic  Don't know/refused          96

# %% [markdown]
# ### 1.5 Having the following list, could you create a column based on `income` having information of the `mean_income`.

# %%
mean_income = [5, 15, 25, 35, 45, 62.5, 87.5, 125, 170, None]

# %%
# here your code

# %%
df.head()
# Out:
#    religion   income  population  mean_income
# 0  Agnostic    <$10k          27          5.0
# 1  Agnostic  $10-20k          34         15.0
# 2  Agnostic  $20-30k          60         25.0
# 3  Agnostic  $30-40k          81         35.0
# 4  Agnostic  $40-50k          76         45.0

# %% [markdown]
# ### 1.6 Create a column called `pct` with the percentage of population `freq` by `religion` and `income`.
#
# Check that the `pct` of Agnostics with income between $50-75k is [link text](https://)0.165860

# %%
# here your code

# %% [markdown]
# ### 1.7 Create a column called `weighted_mean_income` which is the `mean_income` times `pct` calculated before

# %%
# here your code

# %% [markdown]
# ### 1.8 What is the **mean** and **std** of `weighted_mean_income` by religion

# %%
# here your code

# %%
# Out:
#                          weighted_mean_income_mean  weighted_mean_income_std
# religion
# Agnostic                                  7.471415                  6.852753
# Atheist                                   7.659655                  8.104226
# Buddhist                                  7.247905                  7.296950
# Catholic                                  6.086727                  5.064724
# Don’t know/refused                        4.372958                  4.079238
# Evangelical Prot                          5.316166                  3.630505
# Hindu                                     9.746001                 12.730271
# Historically Black Prot                   4.270677                  2.157098
# Jehovah's Witness                         4.378553                  2.507986
# Jewish                                    8.431085                 12.206539
# Mainline Prot                             6.393277                  5.430940
# ...

# %% [markdown]
# ### 1.9 Create a pandas.DataFrame with the previous information, it should by tidy , without multiindexes or multicolumns

# %%
# here your code
# Out:
#                    religion  ...  weighted_mean_income_std
# 0                  Agnostic  ...                  6.852753
# 1                   Atheist  ...                  8.104226
# 2                  Buddhist  ...                  7.296950
# 3                  Catholic  ...                  5.064724
# 4        Don’t know/refused  ...                  4.079238
# 5          Evangelical Prot  ...                  3.630505
# 6                     Hindu  ...                 12.730271
# 7   Historically Black Prot  ...                  2.157098
# 8         Jehovah's Witness  ...                  2.507986
# 9                    Jewish  ...                 12.206539
# 10            Mainline Prot  ...                  5.430940
# 11                   Mormon  ...                  5.307916
# 12                   Muslim  ...                  4.773076
# 13                 Orthodox  ...                  7.185716
# 14          Other Christian  ...                  5.821661
# ...

# %% [markdown]
# ### 1.10 Plot the `weighted_mean_income_mean` versus `weighted_mean_income_std` in a scatter plot ( or any other plot you consider ) and interpret the results

# %%
# here your code

# %%
# here your code
# Out:
# /usr/local/lib/python3.6/dist-packages/plotnine/stats/smoothers.py:168: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
#   "for lowess smoothings.", PlotnineWarning)
# <ggplot: (-9223363305700433720)>
